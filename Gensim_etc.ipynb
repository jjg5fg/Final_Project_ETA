# %%
import pandas as pd
import numpy as np
from gensim.models import word2vec
from gensim.corpora import Dictionary
from sklearn.manifold import TSNE as tsne
import plotly_express as px
import plotly.io as pio
pio.renderers.default = 'notebook_connected'

w2v_params = dict(
    window = 5,
    vector_size = 246,
    min_count = 50, # THIS LIMITS OUR VOCAB
    workers = 4
)
from IPython.display import display

# %%
VOCAB = pd.read_csv('VOCAB.csv').set_index('term_str')
TOKENS = pd.read_csv('CORPUS.csv').set_index('speech_id')
BOW = pd.read_csv('BOW.csv').set_index('term_str')
VOCAB = VOCAB[~VOCAB.index.isna()] # There is NaN in the index for some reason
BOW = BOW[~BOW.index.isna()] # There is NaN in the index for some reason

VOCAB= VOCAB.join(BOW['tfidf'])

# %% [markdown]
# ## VOCAB_W2V

# %%
VOCAB =VOCAB.reset_index()
VOCAB = VOCAB.drop_duplicates(subset='term_str', keep='first').set_index('term_str')

# %%
VOCAB['pos_max'] = TOKENS.groupby(['term_str','pos']).pos.count().unstack().idxmax(axis=1)

# %%
docs = TOKENS[~TOKENS.pos.str.match('NNPS?')].dropna(subset=['term_str'])\
    .groupby('speech_id')\
    .term_str.apply(lambda  x:  x.tolist())\
    .reset_index()['term_str'].tolist()
docs = [doc for doc in docs if len(doc) > 1] # Lose single word docs

vocab = Dictionary(docs)

# %%
model = word2vec.Word2Vec(docs, **w2v_params)

# %%
def get_vector(row):
    w = row.name
    try:
        vec = model.wv[w]
    except KeyError as e:
        vec = None
    return vec

# %%
WV = pd.DataFrame(VOCAB.apply(get_vector, axis=1).dropna()).apply(lambda x: pd.Series(x[0]), axis=1)

# %%
tsne_engine = tsne(perplexity=40, n_components=2, init='pca', n_iter=2500, random_state=23)
tsne_model = tsne_engine.fit_transform(WV.to_numpy())

# %%
TSNE = pd.DataFrame(tsne_model, columns=['x','y'], index=WV.index)

# %%
X = TSNE.join(VOCAB, how='left')

# %%
X
# Out:
#                     x          y     n  n_chars         p          i max_pos  \
# term_str
# 01          48.897690 -22.363218    81        2  0.000021  15.532189      CD
# 03          47.563446 -25.568886    53        2  0.000014  16.144118      CD
# 1          -25.897913  43.851585  1674        1  0.000436  11.162955      CD
# 10          58.060474 -22.678740   467        2  0.000122  13.004760      CD
# 100         56.927952 -20.268248   209        3  0.000054  14.164680      CD
# ...               ...        ...   ...      ...       ...        ...     ...
# yourself   -32.489567  30.633022    70        8  0.000018  15.742756     PRP
# yourselves -32.832424  30.911358    93       10  0.000024  15.332880     NNS
# youth      -26.806528 -18.179283   124        5  0.000032  14.917842      NN
# zeal       -32.148338 -13.733883   118        4  0.000031  14.989396      NN
# zone        19.666887  -7.795245   112        4  0.000029  15.064684      NN
#
#             n_pos                          cat_pos  stop stem_porter  \
# term_str
# 01              1                           {'CD'}     0          01
# 03              1                           {'CD'}     0          03
# 1               3              {'NNP', 'CD', 'NN'}     0           1
# 10              2                     {'JJ', 'CD'}     0          10
# 100             1                           {'CD'}     0         100
# ...           ...                              ...   ...         ...
# yourself        3              {'PRP', 'VB', 'NN'}     1    yourself
# yourselves      3             {'VBZ', 'NNS', 'NN'}     1    yourselv
# youth           5  {'RB', 'NN', 'NNP', 'VB', 'JJ'}     0       youth
# zeal            1                           {'NN'}     0        zeal
# zone            2                    {'NNP', 'NN'}     0        zone
#
#            stem_snowball stem_lancaster max_pos_group       dfidf     tfidf  \
# term_str
# 01                    01             01            CD   86.035409  0.021525
# 03                    03             03            CD   90.687760  0.013556
# 1                      1              1            CD  525.369344  0.005546
# 10                    10             10            CD  487.912711  0.022568
# 100                  100            100            CD  403.385836  0.001995
# ...                  ...            ...           ...         ...       ...
# yourself        yourself       yourself            PR  194.638489  0.183816
# yourselves      yourselv       yourselv            NN  245.342238  0.068752
# youth              youth            you            NN  303.276978  0.026920
# zeal                zeal           zeal            NN  311.479934  0.028841
# zone                zone            zon            NN  200.739967  0.016221
#
#            pos_max
# term_str
# 01              CD
# 03              CD
# 1               CD
# 10              CD
# 100             CD
# ...            ...
# yourself       PRP
# yourselves     NNS
# youth           NN
# zeal            NN
# zone            NN
#
# [4800 rows x 17 columns]

# %% [markdown]
# ## Word2vec tSNE Plot

# %%
px.scatter(X.reset_index(), 'x', 'y', 
           text='term_str', 
           color='pos_max', 
           hover_name='term_str',          
           size='tfidf',
           height=1000).update_traces(
                mode='markers+text', 
                textfont=dict(color='black', size=6, family='Arial'),
                textposition='top center')
# Out:
# <div>                            <div id="9109d555-24c2-41cf-9ae2-f65a98127bf7" class="plotly-graph-div" style="height:1000px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9109d555-24c2-41cf-9ae2-f65a98127bf7")) {                    Plotly.newPlot(                        "9109d555-24c2-41cf-9ae2-f65a98127bf7",                        [{"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003epos_max=CD\u003cbr\u003ex=%{x}\u003cbr\u003ey=%{y}\u003cbr\u003etfidf=%{marker.size}\u003cbr\u003eterm_str=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["01","03","1","10","100","1000","10000","100000","10th","11","11th","12","13","14","14th","15","150","15th","16","17","17th","18","1818","1832","1845","1846","1850","1858","1860","1861","1865","1867","1868","1869","1878","1880","1881","1883","1889","1890","1891","1892","1893","1894","1897","1898","1899","19","1900","1903","1909","1911","1960","1964","1980","1st","2","20","200","2000","21","22","23","24","25","26","27","28","2d","3","30","300","3000","30th","31","35","3d","4","40","45","4th","5","50","500","5000","50000","6","60","6th","7","70","75","8","80","8th","9","90","billion","eight","five","four","hundred","million","nine","one","seven","six","thousand","three","trillion","twenty","two"],"legendgroup":"CD","marker":{"color":"#636efa","size":[0.0215249958848647,0.0135557189497263,0.0055456145933497,0.0225676554415379,0.0019948856955281,0.0203646291925286,0.0064589136046897,0.0303461023250521,0.1286336986749757,0.0350523999198183,0.0073517578721944,0.0117202287178262,0.0083930362039881,0.0068496361418182,0.033097132013171,0.0121116888044437,0.0104024477148674,0.0762935413522545,0.0027236623923634,0.0048644506746075,0.0325602146996318,0.0158368082894504,0.0237662185918193,0.017821871232076,0.0056472814899845,0.1659026580441176,0.0024330362316277,0.009638912745992,0.0102836630127268,0.0244638625371505,0.0039220633195218,0.0057517714598177,0.0046764139495625,0.0051533121634918,0.0071936111889048,0.0080911762908039,0.1687413350551249,0.0261227899049049,0.0128046681394563,0.0075927872608925,0.0068034828209642,0.0053503103111309,0.0133494766185885,0.0185528235283246,0.0076513383639929,0.2588148368341951,0.0077009853698356,0.0411175678885236,0.025854618088275,0.1929629923171312,0.0059903845216042,0.0101414710894223,0.0306590784983601,0.0318422515753682,0.0164968479762363,0.0218985790552434,0.0168876213145627,0.0064453083270637,0.0039206125027647,0.0161231650677403,0.0217313950153246,0.0063904737285628,0.0869248899304263,0.0241579900371009,0.0066418606238698,0.0184489990944248,0.0280261988640935,0.022476948064322,0.1296483063423399,0.0126658916000354,0.012099745486585,0.0234712266256849,0.0036770726990125,0.0259400946222049,0.0199084460707674,0.0050289328844611,0.0520316084527991,0.0050147379530296,0.0073172007496939,0.0117688356758909,0.0272675122341048,0.0143418804142399,0.0034965010488769,0.0322287637939136,0.006711658967931,0.0048421382956463,0.0168448935816297,0.0067816855624699,0.0484063310505953,0.0132753642778862,0.003197963387097,0.0138614705909049,0.0228532272134111,0.0773145732553708,0.0338105289399196,0.0202878482736286,0.037422360946898,0.0251849457429211,0.1408745706269605,0.0254436032126723,0.0061810177779047,0.0170815806564069,0.0102491143243883,0.0144546734624239,0.0073384269253332,0.0100111596449095,0.0751402989751459,0.2677210853735564,0.0089429833131142,0.0167097790638851,0.0369364390816179,0.0046258996510633],"sizemode":"area","sizeref":0.0015928884602372504,"symbol":"circle"},"mode":"markers+text","name":"CD","showlegend":true,"text":["01","03","1","10","100","1000","10000","100000","10th","11","11th","12","13","14","14th","15","150","15th","16","17","17th","18","1818","1832","1845","1846","1850","1858","1860","1861","1865","1867"," ...
